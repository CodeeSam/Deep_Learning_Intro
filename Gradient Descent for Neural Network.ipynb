# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('insurance_data.csv')
df.head(6)
# Out:
#    age  affordibility  bought_insurance
# 0   22              1                 0
# 1   25              0                 0
# 2   47              1                 1
# 3   52              0                 0
# 4   46              1                 1
# 5   56              1                 1

# %%
df.age.min(), df.age.max()
# Out:
# (18, 62)

# %%
len(df), df.shape
# Out:
# (28, (28, 3))

# %%
X = df.drop('bought_insurance', axis=1)
X.head()
# Out:
#    age  affordibility
# 0   22              1
# 1   25              0
# 2   47              1
# 3   52              0
# 4   46              1

# %%
y = df.bought_insurance
y.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: bought_insurance, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=25)

# %%
len(X_train), len(X_test)
# Out:
# (22, 6)

# %%
len(X_train), len(y_train)
# Out:
# (22, 22)

# %%
len(X_test), len(y_test)
# Out:
# (6, 6)

# %%
# Let's scale the input, age precisely

# %%
# We need to do some scaling in the above data.
# The affordability value ranges between 0 and 1, whereas the age values is just not definite

# %%
df.age.max()
# Out:
# 62

# %% [markdown]
# ##### scaling the age for the training data

# %%
X_train_scaled = X_train.copy()
X_train_scaled.age = X_train_scaled.age/100

# %%
X_train_scaled.age
# Out:
# 0     0.22
# 13    0.29
# 6     0.55
# 17    0.58
# 24    0.50
# 19    0.18
# 25    0.54
# 16    0.25
# 20    0.21
# 3     0.52
# 7     0.60
# 1     0.25
# 5     0.56
# 27    0.46
# 8     0.62
# 18    0.19
# 12    0.27
# 23    0.45
# 22    0.40
# 15    0.55
# 26    0.23
# 4     0.46
# Name: age, dtype: float64

# %%
X_train_scaled.age.max(), X_train_scaled.age.min()
# Out:
# (0.62, 0.18)

# %% [markdown]
# ##### scaling the age for the test data

# %%
X_test_scaled = X_test.copy()
X_test_scaled.age = X_test_scaled.age/100

# %%
X_test_scaled.age.max(), X_test_scaled.age.min()
# Out:
# (0.61, 0.18)

# %%
X_test_scaled
# Out:
#      age  affordibility
# 2   0.47              1
# 10  0.18              1
# 21  0.26              0
# 11  0.28              1
# 14  0.49              1
# 9   0.61              1

# %%
model = keras.Sequential([
    keras.layers.Dense(1, input_shape=(2,), activation='sigmoid', kernel_initializer='ones', bias_initializer='zeros')])

model.compile(
    optimizer = 'adam',
    loss = 'binary_crossentropy',
    metrics = ['accuracy']
)

model.fit(X_train_scaled, y_train, epochs=5000) #the value of epoch(5000) here was gotten by trial and errror, 5000 gave the best
# Out:
# Epoch 1/5000
# 1/1 [==============================] - 2s 2s/step - loss: 0.7113 - accuracy: 0.5000
# Epoch 2/5000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.7110 - accuracy: 0.5000
# Epoch 3/5000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.7106 - accuracy: 0.5000
# Epoch 4/5000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.7102 - accuracy: 0.5000
# Epoch 5/5000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.7098 - accuracy: 0.5000
# Epoch 6/5000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.7094 - accuracy: 0.5000
# Epoch 7/5000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.7091 - accuracy: 0.5000
# Epoch 8/5000
# 1/1 [==============================] - 0s 27ms/step - loss: 0.7087 - accuracy: 0.5000
# Epoch 9/5000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.7083 - accuracy: 0.5000
# Epoch 10/5000
# ...

# %%
model.evaluate(X_test_scaled, y_test)
# Out:
# 1/1 [==============================] - 1s 532ms/step - loss: 0.3550 - accuracy: 1.0000
# [0.3549776077270508, 1.0]

# %%
X_test_scaled
# Out:
#      age  affordibility
# 2   0.47              1
# 10  0.18              1
# 21  0.26              0
# 11  0.28              1
# 14  0.49              1
# 9   0.61              1

# %%
model.predict(X_test_scaled) ###any value that is above 0.5 is counted as 1(i.e. will buy the insurance)
# Out:
# 1/1 [==============================] - 0s 283ms/step
# array([[0.7054848 ],
#        [0.3556957 ],
#        [0.16827832],
#        [0.47801185],
#        [0.7260696 ],
#        [0.8294983 ]], dtype=float32)

# %%
y_test # our predictions are all correct
# Out:
# 2     1
# 10    0
# 21    0
# 11    0
# 14    1
# 9     1
# Name: bought_insurance, dtype: int64

# %%
###to get the weight and bias(coefficient and intercept)
coef, intercept = model.get_weights()
coef, intercept #(the two values in coef array represent w1 and w2, while the value in the intercept array is the bias)
# Out:
# (array([[5.060863 ],
#         [1.4086521]], dtype=float32),
#  array([-2.913703], dtype=float32))

# %%
## ... from scratch ...

# %%
def sigmoid(z):
    import math
    return 1/(1+math.exp(-z))

# %%
coef, coef[0], coef[1]
# Out:
# (array([[5.060863 ],
#         [1.4086521]], dtype=float32),
#  array([5.060863], dtype=float32),
#  array([1.4086521], dtype=float32))

# %%
def prediction_function(age, affordability):
    weighted_sum = coef[0]*age + coef[1]*affordability + intercept
    return sigmoid(weighted_sum)

# %%
prediction_function(.47, 1)
# Out:
# 0.705484819775958

# %%
def log_loss(y_true, y_predicted):
    epsilon = 1e-15
    y_predicted_new = [max(i,epsilon) for i in y_predicted]
    y_predicted_new = [min(i,1-epsilon) for i in y_predicted_new]
    y_predicted_new = np.array(y_predicted_new)
    return -np.mean(y_true*np.log(y_predicted_new)+(1-y_true)*np.log(1-y_predicted_new))

# %%
def sigmoid_numpy(X):
    return 1/(1+np.exp(-X))

# %%
sigmoid_numpy(np.array([12,0,1]))
# Out:
# array([0.99999386, 0.5       , 0.73105858])

# %%
def gradient_descent(age, affordability, y_true, epochs):
    #w1, w2, bias
    w1 = w2 = 1
    bias = 0
    rate = 0.5
    n = len(age) #could also be len(affordability)
    
    for i in range(epochs):
        weighted_sum = w1*age + w2*affordability + bias
        y_predicted = sigmoid_numpy(weighted_sum)
        loss = log_loss(y_true, y_predicted)
        w1d = (1/n)*np.dot(np.transpose(age), (y_predicted-y_true))
        w2d = (1/n)*np.dot(np.transpose(affordability), (y_predicted-y_true))
        bias_d = np.mean(y_predicted-y_true)
        
        w1 = w1 - rate*w1d
        w2 = w2 - rate*w2d
        bias = bias - rate*bias
        
        print(f'Epoch:{i}, w1:{w1}, w2:{w2}, bias:{bias}, loss:{loss}')
    
    return w1,w2,bias

# %%
gradient_descent(X_train_scaled['age'], X_train_scaled.affordibility, y_train, 1000)
# Out:
# Epoch:0, w1:0.974907633470177, w2:0.948348125394529, bias:0.0, loss:0.7113403233723417
# Epoch:1, w1:0.951309050414721, w2:0.8998384766138976, bias:0.0, loss:0.7049437880152859
# Epoch:2, w1:0.9291619684235712, w2:0.8543880770572044, bias:0.0, loss:0.6993052593238982
# Epoch:3, w1:0.9084179079556838, w2:0.8118995045564921, bias:0.0, loss:0.6943576384281475
# Epoch:4, w1:0.8890233255496454, w2:0.7722634615046652, bias:0.0, loss:0.6900349522584057
# Epoch:5, w1:0.870920747167955, w2:0.7353613402471417, bias:0.0, loss:0.6862734824669942
# Epoch:6, w1:0.854049860257641, w2:0.7010676910254683, bias:0.0, loss:0.6830126499196405
# Epoch:7, w1:0.8383485325252197, w2:0.6692525213982417, bias:0.0, loss:0.6801956585346196
# Epoch:8, w1:0.8237537349858943, w2:0.6397833777872467, bias:0.0, loss:0.6777699161231555
# Epoch:9, w1:0.8102023557195147, w2:0.6125271797757017, bias:0.0, loss:0.6756872590878301
# Epoch:10, w1:0.7976318984134669, w2:0.5873517948751835, bias:0.0, loss:0.6739040127414273
# ...
